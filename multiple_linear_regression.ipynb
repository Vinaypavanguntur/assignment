# %%
import pandas as pd

df = pd.read_json(r'C:\Users\vinay\STREET GROUP\street_group_data_science_bedrooms_test.json', lines=True)

df.head()
# Out:
#        property_type  total_floor_area  number_habitable_rooms  \
# 0  Flats/Maisonettes              39.0                       1
# 1  Flats/Maisonettes              24.0                       1
# 2  Flats/Maisonettes              25.0                       1
# 3  Flats/Maisonettes              27.0                       1
# 4  Flats/Maisonettes              29.0                       1
#
#    number_heated_rooms  estimated_min_price  estimated_max_price   latitude  \
# 0                    1               103000               126000  52.164661
# 1                    1                36000                44000  52.523281
# 2                    1               187000               229000  51.386343
# 3                    1               234000               350000  51.416946
# 4                    1               185000               277000  52.915728
#
#    longitude  bedrooms
# 0  -1.856154         0
# 1  -2.054445         0
# 2  -0.108323         0
# 3  -0.151787         2
# 4  -1.475258         1

# %%
df
# Out:
#             property_type  total_floor_area  number_habitable_rooms  \
# 0       Flats/Maisonettes             39.00                       1
# 1       Flats/Maisonettes             24.00                       1
# 2       Flats/Maisonettes             25.00                       1
# 3       Flats/Maisonettes             27.00                       1
# 4       Flats/Maisonettes             29.00                       1
# ...                   ...               ...                     ...
# 999995           Detached            241.00                      10
# 999996           Detached            286.00                      10
# 999997      Semi-Detached            250.00                      10
# 999998      Semi-Detached            218.00                      10
# 999999           Detached            373.04                      10
#
#         number_heated_rooms  estimated_min_price  estimated_max_price  \
# 0                         1               103000               126000
# 1                         1                36000                44000
# 2                         1               187000               229000
# 3                         1               234000               350000
# 4                         1               185000               277000
# ...                     ...                  ...                  ...
# 999995                   10              1480000              1800000
# 999996                   10              1630000              1800000
# 999997                   10              1240000              1510000
# 999998                   10               454000               682000
# 999999                   10              1400000              2100000
#
#          latitude  longitude  bedrooms
# 0       52.164661  -1.856154         0
# 1       52.523281  -2.054445         0
# 2       51.386343  -0.108323         0
# 3       51.416946  -0.151787         2
# 4       52.915728  -1.475258         1
# ...           ...        ...       ...
# 999995  51.329410  -0.362611         3
# 999996  51.380529  -0.430064         5
# 999997  51.309676  -0.306065         4
# 999998  54.160256  -0.778915         4
# 999999  54.062335  -1.324595         5
#
# [1000000 rows x 9 columns]

# %%
df.head()
# Out:
#        property_type  total_floor_area  number_habitable_rooms  \
# 0  Flats/Maisonettes              39.0                       1
# 1  Flats/Maisonettes              24.0                       1
# 2  Flats/Maisonettes              25.0                       1
# 3  Flats/Maisonettes              27.0                       1
# 4  Flats/Maisonettes              29.0                       1
#
#    number_heated_rooms  estimated_min_price  estimated_max_price   latitude  \
# 0                    1               103000               126000  52.164661
# 1                    1                36000                44000  52.523281
# 2                    1               187000               229000  51.386343
# 3                    1               234000               350000  51.416946
# 4                    1               185000               277000  52.915728
#
#    longitude  bedrooms
# 0  -1.856154         0
# 1  -2.054445         0
# 2  -0.108323         0
# 3  -0.151787         2
# 4  -1.475258         1

# %%
df.tail()
# Out:
#         property_type  total_floor_area  number_habitable_rooms  \
# 999995       Detached            241.00                      10
# 999996       Detached            286.00                      10
# 999997  Semi-Detached            250.00                      10
# 999998  Semi-Detached            218.00                      10
# 999999       Detached            373.04                      10
#
#         number_heated_rooms  estimated_min_price  estimated_max_price  \
# 999995                   10              1480000              1800000
# 999996                   10              1630000              1800000
# 999997                   10              1240000              1510000
# 999998                   10               454000               682000
# 999999                   10              1400000              2100000
#
#          latitude  longitude  bedrooms
# 999995  51.329410  -0.362611         3
# 999996  51.380529  -0.430064         5
# 999997  51.309676  -0.306065         4
# 999998  54.160256  -0.778915         4
# 999999  54.062335  -1.324595         5

# %%
df.shape
# Out:
# (1000000, 9)

# %%
df.corr()
# Out:
#                         total_floor_area  number_habitable_rooms  \
# total_floor_area                1.000000                0.460740
# number_habitable_rooms          0.460740                1.000000
# number_heated_rooms             0.454678                0.945555
# estimated_min_price             0.345473                0.434507
# estimated_max_price             0.348746                0.426805
# latitude                       -0.016168                0.018088
# longitude                      -0.004500               -0.043237
# bedrooms                        0.418689                0.794582
#
#                         number_heated_rooms  estimated_min_price  \
# total_floor_area                   0.454678             0.345473
# number_habitable_rooms             0.945555             0.434507
# number_heated_rooms                1.000000             0.438746
# estimated_min_price                0.438746             1.000000
# estimated_max_price                0.430016             0.990842
# latitude                           0.018622            -0.330046
# longitude                         -0.030087             0.254032
# bedrooms                           0.781890             0.425422
#
#                         estimated_max_price  latitude  longitude  bedrooms
# total_floor_area                   0.348746 -0.016168  -0.004500  0.418689
# number_habitable_rooms             0.426805  0.018088  -0.043237  0.794582
# number_heated_rooms                0.430016  0.018622  -0.030087  0.781890
# estimated_min_price                0.990842 -0.330046   0.254032  0.425422
# estimated_max_price                1.000000 -0.311380   0.239182  0.413248
# latitude                          -0.311380  1.000000  -0.195584  0.001155
# longitude                          0.239182 -0.195584   1.000000 -0.026104
# bedrooms                           0.413248  0.001155  -0.026104  1.000000

# %%
df.columns
# Out:
# Index(['property_type', 'total_floor_area', 'number_habitable_rooms',
#        'number_heated_rooms', 'estimated_min_price', 'estimated_max_price',
#        'latitude', 'longitude', 'bedrooms'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   property_type           1000000 non-null  object
#  1   total_floor_area        1000000 non-null  float64
#  2   number_habitable_rooms  1000000 non-null  int64
#  3   number_heated_rooms     1000000 non-null  int64
#  4   estimated_min_price     1000000 non-null  int64
#  5   estimated_max_price     1000000 non-null  int64
#  6   latitude                1000000 non-null  float64
#  7   longitude               1000000 non-null  float64
#  8   bedrooms                1000000 non-null  int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 68.7+ MB

# %%
df.isnull().count()
# Out:
# property_type             1000000
# total_floor_area          1000000
# number_habitable_rooms    1000000
# number_heated_rooms       1000000
# estimated_min_price       1000000
# estimated_max_price       1000000
# latitude                  1000000
# longitude                 1000000
# bedrooms                  1000000
# dtype: int64

# %%
df.describe()
# Out:
#        total_floor_area  number_habitable_rooms  number_heated_rooms  \
# count    1000000.000000          1000000.000000       1000000.000000
# mean          95.110280                4.731386             4.644062
# std           77.209212                1.662938             1.677080
# min            0.000000                1.000000             0.000000
# 25%           68.812750                4.000000             4.000000
# 50%           85.000000                5.000000             5.000000
# 75%          108.000000                6.000000             5.000000
# max        60506.700000               83.000000            83.000000
#
#        estimated_min_price  estimated_max_price        latitude  \
# count         1.000000e+06         1.000000e+06  1000000.000000
# mean          3.258840e+05         3.768346e+05       52.341382
# std           2.946820e+05         3.555607e+05        1.130432
# min           1.000000e+04         1.500000e+04       49.912711
# 25%           1.670000e+05         1.920000e+05       51.460908
# 50%           2.560000e+05         2.930000e+05       52.093607
# 75%           3.920000e+05         4.490000e+05       53.359308
# max           1.906000e+07         2.858000e+07       55.879634
#
#             longitude        bedrooms
# count  1000000.000000  1000000.000000
# mean        -1.304311        2.869454
# std          1.298806        0.978529
# min         -6.312345        0.000000
# 25%         -2.187930        2.000000
# 50%         -1.328639        3.000000
# 75%         -0.251483        3.000000
# max          1.757928        9.000000

# %%
df.head(5)
# Out:
#        property_type  total_floor_area  number_habitable_rooms  \
# 0  Flats/Maisonettes              39.0                       1
# 1  Flats/Maisonettes              24.0                       1
# 2  Flats/Maisonettes              25.0                       1
# 3  Flats/Maisonettes              27.0                       1
# 4  Flats/Maisonettes              29.0                       1
#
#    number_heated_rooms  estimated_min_price  estimated_max_price   latitude  \
# 0                    1               103000               126000  52.164661
# 1                    1                36000                44000  52.523281
# 2                    1               187000               229000  51.386343
# 3                    1               234000               350000  51.416946
# 4                    1               185000               277000  52.915728
#
#    longitude  bedrooms
# 0  -1.856154         0
# 1  -2.054445         0
# 2  -0.108323         0
# 3  -0.151787         2
# 4  -1.475258         1

# %%
df.describe().style.background_gradient(cmap='CMRmap')
# Out:
# <style  type="text/css" >
# #T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col0,#T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col1,#T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col2,#T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col5,#T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col6,#T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col7,#T_5e027ca0_44c5_11ec_a603_d068e205b866row7_col3,#T_5e027ca0_44c5_11ec_a603_d068e205b866row7_col4{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col3{
#             background-color:  #101034;
#             color:  #f1f1f1;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col4{
#             background-color:  #0a0a20;
#             color:  #f1f1f1;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col0,#T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col1,#T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col2,#T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col5,#T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col6,#T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col7,#T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col0,#T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col1,#T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col2,#T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col5,#T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col6,#T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col7,#T_5e027ca0_44c5_11ec_a603_d068e205b866row3_col0,#T_5e027ca0_44c5_11ec_a603_d068e205b866row3_col1,#T_5e027ca0_44c5_11ec_a603_d068e205b866row3_col2,#T_5e027ca0_44c5_11ec_a603_d068e205b866row3_col3,#T_5e027ca0_44c5_11ec_a603_d068e205b866row3_col4,#T_5e027ca0_44c5_11ec_a603_d068e205b866row3_col5,#T_5e027ca0_44c5_11ec_a603_d068e205b866row3_col6,#T_5e027ca0_44c5_11ec_a603_d068e205b866row3_col7,#T_5e027ca0_44c5_11ec_a603_d068e205b866row4_col0,#T_5e027ca0_44c5_11ec_a603_d068e205b866row4_col1,#T_5e027ca0_44c5_11ec_a603_d068e205b866row4_col2,#T_5e027ca0_44c5_11ec_a603_d068e205b866row4_col5,#T_5e027ca0_44c5_11ec_a603_d068e205b866row4_col6,#T_5e027ca0_44c5_11ec_a603_d068e205b866row4_col7,#T_5e027ca0_44c5_11ec_a603_d068e205b866row5_col0,#T_5e027ca0_44c5_11ec_a603_d068e205b866row5_col1,#T_5e027ca0_44c5_11ec_a603_d068e205b866row5_col2,#T_5e027ca0_44c5_11ec_a603_d068e205b866row5_col5,#T_5e027ca0_44c5_11ec_a603_d068e205b866row5_col6,#T_5e027ca0_44c5_11ec_a603_d068e205b866row5_col7,#T_5e027ca0_44c5_11ec_a603_d068e205b866row6_col0,#T_5e027ca0_44c5_11ec_a603_d068e205b866row6_col1,#T_5e027ca0_44c5_11ec_a603_d068e205b866row6_col2,#T_5e027ca0_44c5_11ec_a603_d068e205b866row6_col5,#T_5e027ca0_44c5_11ec_a603_d068e205b866row6_col6,#T_5e027ca0_44c5_11ec_a603_d068e205b866row6_col7,#T_5e027ca0_44c5_11ec_a603_d068e205b866row7_col1,#T_5e027ca0_44c5_11ec_a603_d068e205b866row7_col2,#T_5e027ca0_44c5_11ec_a603_d068e205b866row7_col5,#T_5e027ca0_44c5_11ec_a603_d068e205b866row7_col6,#T_5e027ca0_44c5_11ec_a603_d068e205b866row7_col7{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col3{
#             background-color:  #050510;
#             color:  #f1f1f1;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col4,#T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col3,#T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col4,#T_5e027ca0_44c5_11ec_a603_d068e205b866row5_col3,#T_5e027ca0_44c5_11ec_a603_d068e205b866row6_col4{
#             background-color:  #04040c;
#             color:  #f1f1f1;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row4_col3,#T_5e027ca0_44c5_11ec_a603_d068e205b866row5_col4{
#             background-color:  #020208;
#             color:  #f1f1f1;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row4_col4{
#             background-color:  #010104;
#             color:  #f1f1f1;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row6_col3{
#             background-color:  #060614;
#             color:  #f1f1f1;
#         }#T_5e027ca0_44c5_11ec_a603_d068e205b866row7_col0{
#             background-color:  #12123c;
#             color:  #f1f1f1;
#         }</style><table id="T_5e027ca0_44c5_11ec_a603_d068e205b866" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_floor_area</th>        <th class="col_heading level0 col1" >number_habitable_rooms</th>        <th class="col_heading level0 col2" >number_heated_rooms</th>        <th class="col_heading level0 col3" >estimated_min_price</th>        <th class="col_heading level0 col4" >estimated_max_price</th>        <th class="col_heading level0 col5" >latitude</th>        <th class="col_heading level0 col6" >longitude</th>        <th class="col_heading level0 col7" >bedrooms</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e027ca0_44c5_11ec_a603_d068e205b866level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col0" class="data row0 col0" >1000000.000000</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col1" class="data row0 col1" >1000000.000000</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col2" class="data row0 col2" >1000000.000000</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col3" class="data row0 col3" >1000000.000000</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col4" class="data row0 col4" >1000000.000000</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col5" class="data row0 col5" >1000000.000000</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col6" class="data row0 col6" >1000000.000000</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row0_col7" class="data row0 col7" >1000000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_5e027ca0_44c5_11ec_a603_d068e205b866level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col0" class="data row1 col0" >95.110280</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col1" class="data row1 col1" >4.731386</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col2" class="data row1 col2" >4.644062</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col3" class="data row1 col3" >325884.045786</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col4" class="data row1 col4" >376834.613625</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col5" class="data row1 col5" >52.341382</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col6" class="data row1 col6" >-1.304311</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row1_col7" class="data row1 col7" >2.869454</td>
#             </tr>
#             <tr>
#                         <th id="T_5e027ca0_44c5_11ec_a603_d068e205b866level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col0" class="data row2 col0" >77.209212</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col1" class="data row2 col1" >1.662938</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col2" class="data row2 col2" >1.677080</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col3" class="data row2 col3" >294681.994577</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col4" class="data row2 col4" >355560.704964</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col5" class="data row2 col5" >1.130432</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col6" class="data row2 col6" >1.298806</td>
#                         <td id="T_5e027ca0_44c5_11ec_a603_d068e205b866row2_col7" class="data row2 col7" >0.9785

# %%
df['avg_price'] = df[['estimated_min_price', 'estimated_max_price']].mean(axis=1)

# %%
df
# Out:
#             property_type  total_floor_area  number_habitable_rooms  \
# 0       Flats/Maisonettes             39.00                       1
# 1       Flats/Maisonettes             24.00                       1
# 2       Flats/Maisonettes             25.00                       1
# 3       Flats/Maisonettes             27.00                       1
# 4       Flats/Maisonettes             29.00                       1
# ...                   ...               ...                     ...
# 999995           Detached            241.00                      10
# 999996           Detached            286.00                      10
# 999997      Semi-Detached            250.00                      10
# 999998      Semi-Detached            218.00                      10
# 999999           Detached            373.04                      10
#
#         number_heated_rooms  estimated_min_price  estimated_max_price  \
# 0                         1               103000               126000
# 1                         1                36000                44000
# 2                         1               187000               229000
# 3                         1               234000               350000
# 4                         1               185000               277000
# ...                     ...                  ...                  ...
# 999995                   10              1480000              1800000
# 999996                   10              1630000              1800000
# 999997                   10              1240000              1510000
# 999998                   10               454000               682000
# 999999                   10              1400000              2100000
#
#          latitude  longitude  bedrooms  avg_price
# 0       52.164661  -1.856154         0   114500.0
# 1       52.523281  -2.054445         0    40000.0
# 2       51.386343  -0.108323         0   208000.0
# 3       51.416946  -0.151787         2   292000.0
# 4       52.915728  -1.475258         1   231000.0
# ...           ...        ...       ...        ...
# 999995  51.329410  -0.362611         3  1640000.0
# 999996  51.380529  -0.430064         5  1715000.0
# 999997  51.309676  -0.306065         4  1375000.0
# 999998  54.160256  -0.778915         4   568000.0
# 999999  54.062335  -1.324595         5  1750000.0
#
# [1000000 rows x 10 columns]

# %%
del df['estimated_min_price']

# %%
del df['estimated_max_price']

# %%
df
# Out:
#             property_type  total_floor_area  number_habitable_rooms  \
# 0       Flats/Maisonettes             39.00                       1
# 1       Flats/Maisonettes             24.00                       1
# 2       Flats/Maisonettes             25.00                       1
# 3       Flats/Maisonettes             27.00                       1
# 4       Flats/Maisonettes             29.00                       1
# ...                   ...               ...                     ...
# 999995           Detached            241.00                      10
# 999996           Detached            286.00                      10
# 999997      Semi-Detached            250.00                      10
# 999998      Semi-Detached            218.00                      10
# 999999           Detached            373.04                      10
#
#         number_heated_rooms   latitude  longitude  bedrooms  avg_price
# 0                         1  52.164661  -1.856154         0   114500.0
# 1                         1  52.523281  -2.054445         0    40000.0
# 2                         1  51.386343  -0.108323         0   208000.0
# 3                         1  51.416946  -0.151787         2   292000.0
# 4                         1  52.915728  -1.475258         1   231000.0
# ...                     ...        ...        ...       ...        ...
# 999995                   10  51.329410  -0.362611         3  1640000.0
# 999996                   10  51.380529  -0.430064         5  1715000.0
# 999997                   10  51.309676  -0.306065         4  1375000.0
# 999998                   10  54.160256  -0.778915         4   568000.0
# 999999                   10  54.062335  -1.324595         5  1750000.0
#
# [1000000 rows x 8 columns]

# %%
df['total_floor_area'] = df['total_floor_area'].astype(int)
df['avg_price'] = df['avg_price'].astype(int)

# %%
df
# Out:
#             property_type  total_floor_area  number_habitable_rooms  \
# 0       Flats/Maisonettes                39                       1
# 1       Flats/Maisonettes                24                       1
# 2       Flats/Maisonettes                25                       1
# 3       Flats/Maisonettes                27                       1
# 4       Flats/Maisonettes                29                       1
# ...                   ...               ...                     ...
# 999995           Detached               241                      10
# 999996           Detached               286                      10
# 999997      Semi-Detached               250                      10
# 999998      Semi-Detached               218                      10
# 999999           Detached               373                      10
#
#         number_heated_rooms   latitude  longitude  bedrooms  avg_price
# 0                         1  52.164661  -1.856154         0     114500
# 1                         1  52.523281  -2.054445         0      40000
# 2                         1  51.386343  -0.108323         0     208000
# 3                         1  51.416946  -0.151787         2     292000
# 4                         1  52.915728  -1.475258         1     231000
# ...                     ...        ...        ...       ...        ...
# 999995                   10  51.329410  -0.362611         3    1640000
# 999996                   10  51.380529  -0.430064         5    1715000
# 999997                   10  51.309676  -0.306065         4    1375000
# 999998                   10  54.160256  -0.778915         4     568000
# 999999                   10  54.062335  -1.324595         5    1750000
#
# [1000000 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   property_type           1000000 non-null  object
#  1   total_floor_area        1000000 non-null  int32
#  2   number_habitable_rooms  1000000 non-null  int64
#  3   number_heated_rooms     1000000 non-null  int64
#  4   latitude                1000000 non-null  float64
#  5   longitude               1000000 non-null  float64
#  6   bedrooms                1000000 non-null  int64
#  7   avg_price               1000000 non-null  int32
# dtypes: float64(2), int32(2), int64(3), object(1)
# memory usage: 53.4+ MB

# %%
# LABEL ENCODING

# %%
df['property_type'].unique()
# Out:
# array(['Flats/Maisonettes', 'Detached', 'Terraced', 'Semi-Detached'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
df["property_type_N"] = labelencoder.fit_transform(df['property_type'])

# %%
df
# Out:
#             property_type  total_floor_area  number_habitable_rooms  \
# 0       Flats/Maisonettes                39                       1
# 1       Flats/Maisonettes                24                       1
# 2       Flats/Maisonettes                25                       1
# 3       Flats/Maisonettes                27                       1
# 4       Flats/Maisonettes                29                       1
# ...                   ...               ...                     ...
# 999995           Detached               241                      10
# 999996           Detached               286                      10
# 999997      Semi-Detached               250                      10
# 999998      Semi-Detached               218                      10
# 999999           Detached               373                      10
#
#         number_heated_rooms   latitude  longitude  bedrooms  avg_price  \
# 0                         1  52.164661  -1.856154         0     114500
# 1                         1  52.523281  -2.054445         0      40000
# 2                         1  51.386343  -0.108323         0     208000
# 3                         1  51.416946  -0.151787         2     292000
# 4                         1  52.915728  -1.475258         1     231000
# ...                     ...        ...        ...       ...        ...
# 999995                   10  51.329410  -0.362611         3    1640000
# 999996                   10  51.380529  -0.430064         5    1715000
# 999997                   10  51.309676  -0.306065         4    1375000
# 999998                   10  54.160256  -0.778915         4     568000
# 999999                   10  54.062335  -1.324595         5    1750000
#
#         property_type_N
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 999995                0
# 999996                0
# 999997                2
# 999998                2
# 999999                0
#
# [1000000 rows x 9 columns]

# %%
del df['property_type']

# %%
df
# Out:
#         total_floor_area  number_habitable_rooms  number_heated_rooms  \
# 0                     39                       1                    1
# 1                     24                       1                    1
# 2                     25                       1                    1
# 3                     27                       1                    1
# 4                     29                       1                    1
# ...                  ...                     ...                  ...
# 999995               241                      10                   10
# 999996               286                      10                   10
# 999997               250                      10                   10
# 999998               218                      10                   10
# 999999               373                      10                   10
#
#          latitude  longitude  bedrooms  avg_price  property_type_N
# 0       52.164661  -1.856154         0     114500                1
# 1       52.523281  -2.054445         0      40000                1
# 2       51.386343  -0.108323         0     208000                1
# 3       51.416946  -0.151787         2     292000                1
# 4       52.915728  -1.475258         1     231000                1
# ...           ...        ...       ...        ...              ...
# 999995  51.329410  -0.362611         3    1640000                0
# 999996  51.380529  -0.430064         5    1715000                0
# 999997  51.309676  -0.306065         4    1375000                2
# 999998  54.160256  -0.778915         4     568000                2
# 999999  54.062335  -1.324595         5    1750000                0
#
# [1000000 rows x 8 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score 
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso, LassoCV, Ridge, RidgeCV, ElasticNet, ElasticNetCV

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    score = r2_score(actual, pred)
    return print("r2_score:", score, "\n","mae:", mae, "\n","mse:",mse, "\n","rmse:",rmse)

# %%
def train_val(y_train, y_train_pred, y_test, y_pred):
    
    scores = {"train_set": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),                          
    "rmse" : np.sqrt(mean_squared_error(y_train, y_train_pred))},
    
    "test_set": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : np.sqrt(mean_squared_error(y_test, y_pred))}}
    
    return pd.DataFrame(scores)

# %%
X = df.drop('bedrooms', axis=1)
y = df.bedrooms

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.3, random_state=42)

print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (700000, 7)
# Train target shape   :  (700000,)
# Test features shape  :  (300000, 7)
# Test target shape    :  (300000,)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
ln_model = LinearRegression()
ln_model.fit(X_train_scaled, y_train)
y_pred = ln_model.predict(X_test_scaled)
y_train_pred = ln_model.predict(X_train_scaled)
ln_r2 = r2_score(y_test, y_pred)
ln_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

pd.options.display.float_format = '{:.3f}'.format
train_val(y_train, y_train_pred, y_test, y_pred)
# Out:
#       train_set  test_set
# R2        0.652     0.551
# mae       0.397     0.397
# mse       0.333     0.431
# rmse      0.577     0.656

# %%
elastic_model = ElasticNet(max_iter=10000)

param_grid ={"alpha":[0.001, 0.01, 0.02, 0.1, 1, 5,],
            "l1_ratio":[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]}

grid_model = GridSearchCV(estimator = elastic_model, param_grid = param_grid, scoring = 'neg_root_mean_squared_error',
                         cv =10, verbose =2)

# %%
grid_model.fit(X_train_scaled, y_train)
# Out:
# Fitting 10 folds for each of 42 candidates, totalling 420 fits
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.5; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.0s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.7; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.001, l1_ratio=0.9; total time=   0.1s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.1s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.1s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.1s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.1s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.1s
# [CV] END .........................alpha=0.001, l1_ratio=0.95; total time=   0.1s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END .........................alpha=0.001, l1_ratio=0.99; total time=   0.2s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.3s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.2s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.3s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.2s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.3s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.3s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.3s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.3s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.3s
# [CV] END ............................alpha=0.001, l1_ratio=1; total time=   0.3s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.1s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.01, l1_ratio=0.9; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.95; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.01, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.1s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.1s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.1s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.1s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.1s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.1s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.01, l1_ratio=1; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.1; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.5; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.1s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.7; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.02, l1_ratio=0.9; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.95; total time=   0.1s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.1s
# [CV] END ..........................alpha=0.02, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END .............................alpha=0.02, l1_ratio=1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.1s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.1s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.9; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.1s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.95; total time=   0.1s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.1s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.1s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ...........................alpha=0.1, l1_ratio=0.99; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=0.1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.1s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.7; total time=   0.1s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=1, l1_ratio=0.9; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=1, l1_ratio=1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.1s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.1s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.1s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.1; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.5; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.7; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END ..............................alpha=5, l1_ratio=0.9; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.95; total time=   0.1s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END .............................alpha=5, l1_ratio=0.99; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# [CV] END ................................alpha=5, l1_ratio=1; total time=   0.0s
# GridSearchCV(cv=10, estimator=ElasticNet(max_iter=10000),
#              param_grid={'alpha': [0.001, 0.01, 0.02, 0.1, 1, 5],
#                          'l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]},
#              scoring='neg_root_mean_squared_error', verbose=2)

# %%
y_pred = grid_model.predict(X_test_scaled)
y_train_pred = grid_model.predict(X_train_scaled)
grid_r2 = r2_score(y_test, y_pred)
grid_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
train_val(y_train, y_train_pred, y_test, y_pred)
# Out:
#       train_set  test_set
# R2        0.637     0.645
# mae       0.405     0.404
# mse       0.347     0.341
# rmse      0.589     0.584

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=10, random_state=27)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=27)

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.values.reshape(len(y_test),1)),1))
# Out:
# [[5.3 5. ]
#  [2.3 2. ]
#  [3.1 3. ]
#  ...
#  [2.  2. ]
#  [1.4 2. ]
#  [3.  3. ]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.6896456672373495

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
import matplotlib.pyplot as plt
df.hist()
plt.tight_layout()

# %%
df.columns
# Out:
# Index(['property_type', 'total_floor_area', 'number_habitable_rooms',
#        'number_heated_rooms', 'estimated_min_price', 'estimated_max_price',
#        'latitude', 'longitude', 'bedrooms'],
#       dtype='object')

# %%
df['property_type'].unique()
# Out:
# array(['Flats/Maisonettes', 'Detached', 'Terraced', 'Semi-Detached'],
#       dtype=object)

# %%
df['bedrooms'].unique()
# Out:
# array([0, 2, 1, 6, 3, 5, 7, 4, 8, 9], dtype=int64)

# %%
df.nunique()
# Out:
# property_type                  4
# total_floor_area           28369
# number_habitable_rooms        53
# number_heated_rooms           37
# estimated_min_price         1551
# estimated_max_price         1681
# latitude                  503461
# longitude                 518892
# bedrooms                      10
# dtype: int64

# %%
df.loc[df['property_type'] == 'Flats/Maisonettes']
# Out:
#             property_type  total_floor_area  number_habitable_rooms  \
# 0       Flats/Maisonettes             39.00                       1
# 1       Flats/Maisonettes             24.00                       1
# 2       Flats/Maisonettes             25.00                       1
# 3       Flats/Maisonettes             27.00                       1
# 4       Flats/Maisonettes             29.00                       1
# ...                   ...               ...                     ...
# 998282  Flats/Maisonettes            190.00                      10
# 998765  Flats/Maisonettes            227.16                      10
# 999233  Flats/Maisonettes            129.97                      10
# 999414  Flats/Maisonettes            196.90                      10
# 999544  Flats/Maisonettes            147.00                      10
#
#         number_heated_rooms  estimated_min_price  estimated_max_price  \
# 0                         1               103000               126000
# 1                         1                36000                44000
# 2                         1               187000               229000
# 3                         1               234000               350000
# 4                         1               185000               277000
# ...                     ...                  ...                  ...
# 998282                   10               503000               755000
# 998765                    8               521000               575000
# 999233                   10               211000               317000
# 999414                   10               321000               481000
# 999544                   10               830000              1010000
#
#          latitude  longitude  bedrooms
# 0       52.164661  -1.856154         0
# 1       52.523281  -2.054445         0
# 2       51.386343  -0.108323         0
# 3       51.416946  -0.151787         2
# 4       52.915728  -1.475258         1
# ...           ...        ...       ...
# 998282  54.000631  -1.537363         6
# 998765  53.738248  -2.984344         6
# 999233  52.053834   1.146229         3
# 999414  51.453860  -2.603279         8
# 999544  50.851404   0.556137         8
#
# [139708 rows x 9 columns]

# %%
df.loc[df['bedrooms'] == 6]
# Out:
#         property_type  total_floor_area  number_habitable_rooms  \
# 5            Detached             270.0                      11
# 9            Detached             298.0                      12
# 23           Detached             189.0                      11
# 34           Detached             411.0                      11
# 45           Detached             237.0                      11
# ...               ...               ...                     ...
# 999969       Detached             283.0                      10
# 999973  Semi-Detached             168.0                      10
# 999982       Detached             372.0                      10
# 999985  Semi-Detached             172.0                      10
# 999993  Semi-Detached             224.0                      10
#
#         number_heated_rooms  estimated_min_price  estimated_max_price  \
# 5                        11               475000               580000
# 9                        12               973000              1070000
# 23                       11               554000               612000
# 34                       11               911000              1370000
# 45                       11               608000               672000
# ...                     ...                  ...                  ...
# 999969                   10               824000              1010000
# 999973                   10              1390000              1540000
# 999982                   10              1570000              1920000
# 999985                   10               258000               316000
# 999993                   10               389000               430000
#
#          latitude  longitude  bedrooms
# 5       52.910147  -1.525024         6
# 9       51.943917   0.690980         6
# 23      53.151576  -2.199774         6
# 34      53.166193  -2.640191         6
# 45      52.434262  -1.865488         6
# ...           ...        ...       ...
# 999969  51.170597  -1.778335         6
# 999973  51.430730  -0.334679         6
# 999982  51.137131   0.471090         6
# 999985  52.906224  -2.484262         6
# 999993  51.619747  -3.991559         6
#
# [8427 rows x 9 columns]

# %%
df.loc[df['bedrooms'] == 9].count()
# Out:
# property_type             172
# total_floor_area          172
# number_habitable_rooms    172
# number_heated_rooms       172
# estimated_min_price       172
# estimated_max_price       172
# latitude                  172
# longitude                 172
# bedrooms                  172
# dtype: int64

# %%
sns.set_style( 'ticks')
sns.countplot(x='bedrooms' ,data = df)
sns.despine(left=True , bottom = True)

# %%
sns.set_style('dark')
sns.countplot(x='property_type' , data=df)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='count'>

# %%
sns.countplot(y="bedrooms", hue="property_type", data=df, palette="YlOrRd",
              order=df.bedrooms.value_counts().iloc[:10].index )
# Out:
# <AxesSubplot:xlabel='count', ylabel='bedrooms'>

# %%
sns.barplot(x="property_type", y="total_floor_area", hue="bedrooms", data=df)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='total_floor_area'>

# %%
df
# Out:
#             property_type  total_floor_area  number_habitable_rooms  \
# 0       Flats/Maisonettes             39.00                       1
# 1       Flats/Maisonettes             24.00                       1
# 2       Flats/Maisonettes             25.00                       1
# 3       Flats/Maisonettes             27.00                       1
# 4       Flats/Maisonettes             29.00                       1
# ...                   ...               ...                     ...
# 999995           Detached            241.00                      10
# 999996           Detached            286.00                      10
# 999997      Semi-Detached            250.00                      10
# 999998      Semi-Detached            218.00                      10
# 999999           Detached            373.04                      10
#
#         number_heated_rooms  estimated_min_price  estimated_max_price  \
# 0                         1               103000               126000
# 1                         1                36000                44000
# 2                         1               187000               229000
# 3                         1               234000               350000
# 4                         1               185000               277000
# ...                     ...                  ...                  ...
# 999995                   10              1480000              1800000
# 999996                   10              1630000              1800000
# 999997                   10              1240000              1510000
# 999998                   10               454000               682000
# 999999                   10              1400000              2100000
#
#          latitude  longitude  bedrooms
# 0       52.164661  -1.856154         0
# 1       52.523281  -2.054445         0
# 2       51.386343  -0.108323         0
# 3       51.416946  -0.151787         2
# 4       52.915728  -1.475258         1
# ...           ...        ...       ...
# 999995  51.329410  -0.362611         3
# 999996  51.380529  -0.430064         5
# 999997  51.309676  -0.306065         4
# 999998  54.160256  -0.778915         4
# 999999  54.062335  -1.324595         5
#
# [1000000 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
df["property_type_N"] = labelencoder.fit_transform(df['property_type'])

# %%
df
# Out:
#             property_type  total_floor_area  number_habitable_rooms  \
# 0       Flats/Maisonettes             39.00                       1
# 1       Flats/Maisonettes             24.00                       1
# 2       Flats/Maisonettes             25.00                       1
# 3       Flats/Maisonettes             27.00                       1
# 4       Flats/Maisonettes             29.00                       1
# ...                   ...               ...                     ...
# 999995           Detached            241.00                      10
# 999996           Detached            286.00                      10
# 999997      Semi-Detached            250.00                      10
# 999998      Semi-Detached            218.00                      10
# 999999           Detached            373.04                      10
#
#         number_heated_rooms  estimated_min_price  estimated_max_price  \
# 0                         1               103000               126000
# 1                         1                36000                44000
# 2                         1               187000               229000
# 3                         1               234000               350000
# 4                         1               185000               277000
# ...                     ...                  ...                  ...
# 999995                   10              1480000              1800000
# 999996                   10              1630000              1800000
# 999997                   10              1240000              1510000
# 999998                   10               454000               682000
# 999999                   10              1400000              2100000
#
#          latitude  longitude  bedrooms  property_type_N
# 0       52.164661  -1.856154         0                1
# 1       52.523281  -2.054445         0                1
# 2       51.386343  -0.108323         0                1
# 3       51.416946  -0.151787         2                1
# 4       52.915728  -1.475258         1                1
# ...           ...        ...       ...              ...
# 999995  51.329410  -0.362611         3                0
# 999996  51.380529  -0.430064         5                0
# 999997  51.309676  -0.306065         4                2
# 999998  54.160256  -0.778915         4                2
# 999999  54.062335  -1.324595         5                0
#
# [1000000 rows x 10 columns]

# %%
del df['property_type']
del df['latitude']
del df['longitude']

# %%
df
# Out:
#         total_floor_area  number_habitable_rooms  number_heated_rooms  \
# 0                  39.00                       1                    1
# 1                  24.00                       1                    1
# 2                  25.00                       1                    1
# 3                  27.00                       1                    1
# 4                  29.00                       1                    1
# ...                  ...                     ...                  ...
# 999995            241.00                      10                   10
# 999996            286.00                      10                   10
# 999997            250.00                      10                   10
# 999998            218.00                      10                   10
# 999999            373.04                      10                   10
#
#         estimated_min_price  estimated_max_price  bedrooms  property_type_N
# 0                    103000               126000         0                1
# 1                     36000                44000         0                1
# 2                    187000               229000         0                1
# 3                    234000               350000         2                1
# 4                    185000               277000         1                1
# ...                     ...                  ...       ...              ...
# 999995              1480000              1800000         3                0
# 999996              1630000              1800000         5                0
# 999997              1240000              1510000         4                2
# 999998               454000               682000         4                2
# 999999              1400000              2100000         5                0
#
# [1000000 rows x 7 columns]

# %%
df['total_floor_area'] = df['total_floor_area'].astype(int)

# %%
df
# Out:
#         total_floor_area  number_habitable_rooms  number_heated_rooms  \
# 0                     39                       1                    1
# 1                     24                       1                    1
# 2                     25                       1                    1
# 3                     27                       1                    1
# 4                     29                       1                    1
# ...                  ...                     ...                  ...
# 999995               241                      10                   10
# 999996               286                      10                   10
# 999997               250                      10                   10
# 999998               218                      10                   10
# 999999               373                      10                   10
#
#         estimated_min_price  estimated_max_price  bedrooms  property_type_N
# 0                    103000               126000         0                1
# 1                     36000                44000         0                1
# 2                    187000               229000         0                1
# 3                    234000               350000         2                1
# 4                    185000               277000         1                1
# ...                     ...                  ...       ...              ...
# 999995              1480000              1800000         3                0
# 999996              1630000              1800000         5                0
# 999997              1240000              1510000         4                2
# 999998               454000               682000         4                2
# 999999              1400000              2100000         5                0
#
# [1000000 rows x 7 columns]

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['total_floor_area', 'number_habitable_rooms', 'number_heated_rooms',
#        'estimated_min_price', 'estimated_max_price', 'bedrooms',
#        'property_type_N'],
#       dtype='object')

# %%
X = df[['total_floor_area', 'number_habitable_rooms', 'number_heated_rooms',
       'estimated_min_price', 'estimated_max_price',
       'property_type_N']]
y = df['bedrooms']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('std_scalar', StandardScaler())
])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
print(lin_reg.intercept_)
# Out:
# 2.8686957142857143

# %%
coeff_df = pd.DataFrame(lin_reg.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#                         Coefficient
# total_floor_area           0.154048
# number_habitable_rooms     0.419322
# number_heated_rooms        0.235032
# estimated_min_price        0.430184
# estimated_max_price       -0.384255
# property_type_N            0.008395

# %%
pred = lin_reg.predict(X_test)

# %%
import numpy as np
test_pred = lin_reg.predict(X_test)
train_pred = lin_reg.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.3962702532087723
# MSE: 0.4477998252085443
# RMSE: 0.6691784703713534
# R2 Square 0.5331397832703463
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 0.3963558131670365
# MSE: 0.3299296744386342
# RMSE: 0.5743950508479632
# R2 Square 0.6551761155973355
# __________________________________

# %%
results_df = pd.DataFrame(data=[["Linear Regression", *evaluate(y_test, test_pred) , cross_val(LinearRegression())]], 
                          columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df
# Out:
#                Model      MAE     MSE      RMSE  R2 Square  Cross Validation
# 0  Linear Regression  0.39627  0.4478  0.669178    0.53314          0.038626

# %%
from sklearn.linear_model import RANSACRegressor

model = RANSACRegressor(base_estimator=LinearRegression(), max_trials=100)
model.fit(X_train, y_train)

test_pred = model.predict(X_test)
train_pred = model.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('====================================')
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.40462240300283275
# MSE: 0.5472929684292644
# RMSE: 0.7397925171487371
# R2 Square 0.42941176063097164
# __________________________________
# ====================================
# Train set evaluation:
# _____________________________________
# MAE: 0.40433181951232927
# MSE: 0.346193639734518
# RMSE: 0.5883822224834109
# R2 Square 0.638177936519752
# __________________________________

# %%
results_df_2 = pd.DataFrame(data=[["Robust Regression", *evaluate(y_test, test_pred) , cross_val(RANSACRegressor())]], 
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = results_df.append(results_df_2, ignore_index=True)
results_df
# Out:
#                Model       MAE       MSE      RMSE  R2 Square  \
# 0  Linear Regression  0.396270  0.447800  0.669178   0.533140
# 1  Robust Regression  0.404622  0.547293  0.739793   0.429412
#
#    Cross Validation
# 0          0.038626
# 1         -0.474505

# %%
from sklearn.linear_model import Ridge

model = Ridge(alpha=100, solver='cholesky', tol=0.0001, random_state=42)
model.fit(X_train, y_train)
pred = model.predict(X_test)

test_pred = model.predict(X_test)
train_pred = model.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('====================================')
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.39626532615650795
# MSE: 0.4475755476639238
# RMSE: 0.6690108726051647
# R2 Square 0.5333736070844586
# __________________________________
# ====================================
# Train set evaluation:
# _____________________________________
# MAE: 0.39635302556767493
# MSE: 0.32993041651264937
# RMSE: 0.5743956968089589
# R2 Square 0.6551753400234352
# __________________________________

# %%
results_df_2 = pd.DataFrame(data=[["Ridge Regression", *evaluate(y_test, test_pred) , cross_val(Ridge())]], 
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = results_df.append(results_df_2, ignore_index=True)
results_df
# Out:
#                Model       MAE       MSE      RMSE  R2 Square  \
# 0  Linear Regression  0.396270  0.447800  0.669178   0.533140
# 1  Robust Regression  0.404622  0.547293  0.739793   0.429412
# 2   Ridge Regression  0.396265  0.447576  0.669011   0.533374
#
#    Cross Validation
# 0          0.038626
# 1         -0.474505
# 2          0.038626

# %%
from sklearn.linear_model import Lasso

model = Lasso(alpha=0.1, 
              precompute=True, 
#               warm_start=True, 
              positive=True, 
              selection='random',
              random_state=42)
model.fit(X_train, y_train)

test_pred = model.predict(X_test)
train_pred = model.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('====================================')
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.4189043545511498
# MSE: 0.4036858911602229
# RMSE: 0.6353628027829634
# R2 Square 0.5791314064269781
# __________________________________
# ====================================
# Train set evaluation:
# _____________________________________
# MAE: 0.4190622461776026
# MSE: 0.3461179110558494
# RMSE: 0.5883178656609447
# R2 Square 0.6382570838628443
# __________________________________

# %%
results_df_2 = pd.DataFrame(data=[["Lasso Regression", *evaluate(y_test, test_pred) , cross_val(Lasso())]], 
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = results_df.append(results_df_2, ignore_index=True)
results_df
# Out:
#                Model       MAE       MSE      RMSE  R2 Square  \
# 0  Linear Regression  0.396270  0.447800  0.669178   0.533140
# 1  Robust Regression  0.404622  0.547293  0.739793   0.429412
# 2   Ridge Regression  0.396265  0.447576  0.669011   0.533374
# 3   Lasso Regression  0.418904  0.403686  0.635363   0.579131
#
#    Cross Validation
# 0          0.038626
# 1         -0.474505
# 2          0.038626
# 3         -1.428910

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree=2)

X_train_2_d = poly_reg.fit_transform(X_train)
X_test_2_d = poly_reg.transform(X_test)

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train_2_d,y_train)

test_pred = lin_reg.predict(X_test_2_d)
train_pred = lin_reg.predict(X_train_2_d)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('====================================')
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.39417263278345616
# MSE: 98.66452959959643
# RMSE: 9.933002043672216
# R2 Square -101.8641394644252
# __________________________________
# ====================================
# Train set evaluation:
# _____________________________________
# MAE: 0.3763361513477494
# MSE: 0.2932571826495525
# RMSE: 0.5415322544867964
# R2 Square 0.6935041353213934
# __________________________________

# %%
results_df_2 = pd.DataFrame(data=[["Polynomail Regression", *evaluate(y_test, test_pred), 0]], 
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', 'Cross Validation'])
results_df = results_df.append(results_df_2, ignore_index=True)
results_df
# Out:
#                    Model       MAE        MSE      RMSE   R2 Square  \
# 0      Linear Regression  0.396270   0.447800  0.669178    0.533140
# 1      Robust Regression  0.404622   0.547293  0.739793    0.429412
# 2       Ridge Regression  0.396265   0.447576  0.669011    0.533374
# 3       Lasso Regression  0.418904   0.403686  0.635363    0.579131
# 4  Polynomail Regression  0.394173  98.664530  9.933002 -101.864139
#
#    Cross Validation
# 0          0.038626
# 1         -0.474505
# 2          0.038626
# 3         -1.428910
# 4          0.000000
